# %%
# data manipulation 
import numpy as np
import pandas as pd

# plots and graphs
import matplotlib.pyplot as plt

# function fit
from scipy.optimize import curve_fit

# disable warnings
import warnings
warnings.filterwarnings('ignore')

# save output
import os
import csv

# %% [markdown]
# # Chapman-Richards Growth Function

# %%
def growth_curve(age, A, k, p):
    return A * (1 - np.exp(-k * age))**p

# %% [markdown]
# ### Pacific Maritime Data

# %% [markdown]
# #### Hemlock

# %%
# age
x_data_h = np.array([10,30,50,70,90,110,130,150,170,190,210])
# AGB
y_data_h = np.array([29.14, 119.32, 243.39, 329.07, 322.25, 231.83, 249.81, 259.46, 226.53, 197.34, 326.38])

# %%
# [250, 1, 0.1]
params_h, _ = curve_fit(growth_curve, x_data_h, y_data_h, [250, 1, 0.1])
params_h
# Out:
# array([2.66834072e+02, 1.35625702e-01, 4.70027757e+01])

# %%
plt.scatter(x_data_h, y_data_h, label='data', marker='x', c='r')
x = np.linspace(1, 210, 210)
plt.plot(x, growth_curve(x, *params_h), 'b-', label='growth curve')

plt.title('HEMLOCK GROWTH CURVE')
plt.xlabel('Age (years)')
plt.ylabel('AGB (Mg ha-1)')
plt.legend()
plt.show()

# %% [markdown]
# #### Coastal Douglas-Fir

# %%
# age
x_data_cdf = np.array([10,30,50,70,90,110,130,150,170,190,210])
# AGB
y_data_cdf = np.array([19.18, 149.68, 278.83, 393.34, 431.07, 399.65, 447.97, 263.17, 339.13, 353.77, 402.94])

# %%
# [250, 0.5, 0.1]
params_cdf, _ = curve_fit(growth_curve, x_data_cdf, y_data_cdf, [250, 0.5, 0.1])
params_cdf
# Out:
# array([3.78949151e+02, 7.39702153e-02, 8.43183031e+00])

# %%
plt.scatter(x_data_cdf, y_data_cdf, label='data', marker='x', c='r')
x = np.linspace(1, 210, 210)
plt.plot(x, growth_curve(x, *params_cdf), 'b-', label='growth curve')

plt.title('COASTAL DOUGLAS-FIR GROWTH CURVE')
plt.xlabel('Age (years)')
plt.ylabel('AGB (Mg ha-1)')
plt.legend()
plt.show()

# %% [markdown]
# I couldn't guess the parameters for other datasets.

# %% [markdown]
# # Another function

# %%
def growth_curve_1(age, A, k, p): 
    return A / (k+np.power(age, p))

# %% [markdown]
# ### Testing on Carpathians Data

# %%
# age
x_data_ns = np.array([14, 18, 28, 43, 43, 43, 99, 99, 99, 105, 114, 119])
# AGB
y_data_ns = np.array([20.99, 31.95, 20.73, 111.71, 112.91, 45.71, 296.97, 104.5, 162.8, 155.73, 199.07, 224.54])

# %%
params_ns, _ = curve_fit(growth_curve_1, x_data_ns, y_data_ns, [1, 1, 1])
params_ns
# Out:
# array([ 1.91204310e-01,  6.43466584e-04, -1.70482349e+00])

# %%
plt.scatter(x_data_ns, y_data_ns, label='data', marker='x', c='r')
x = np.linspace(1, 120, 120)
plt.plot(x, growth_curve_1(x, *params_ns), 'b-', label='growth curve')

plt.title('NORWAY SPRUCE GROWTH CURVE')
plt.xlabel('Age (years)')
plt.ylabel('AGB (Mg ha-1)')
plt.legend()
plt.show()

# %% [markdown]
# ### Pacific Maritime Data

# %% [markdown]
# #### Hemlock

# %%
# age
x_data_h = np.array([10,30,50,70,90,110,130,150,170,190,210])
# AGB
y_data_h = np.array([29.14, 119.32, 243.39, 329.07, 322.25, 231.83, 249.81, 259.46, 226.53, 197.34, 326.38])

# %%
params_h_1, _ = curve_fit(growth_curve_1, x_data_h, y_data_h, [1, 1, 1])
params_h_1
# Out:
# array([ 2.46237481e-08,  9.24077053e-11, -6.72855789e+00])

# %%
plt.scatter(x_data_h, y_data_h, label='data', marker='x', c='r')
x = np.linspace(1, 210, 210)
plt.plot(x, growth_curve_1(x, *params_h_1), 'b-', label='growth curve')

plt.title('HEMLOCK GROWTH CURVE')
plt.xlabel('Age (years)')
plt.ylabel('AGB (Mg ha-1)')
plt.legend()
plt.show()

# %% [markdown]
# #### Coastal Douglas-Fir

# %%
# age
x_data_cdf = np.array([10,30,50,70,90,110,130,150,170,190,210])
# AGB
y_data_cdf = np.array([19.18, 149.68, 278.83, 393.34, 431.07, 399.65, 447.97, 263.17, 339.13, 353.77, 402.94])

# %%
params_cdf_1, _ = curve_fit(growth_curve_1, x_data_cdf, y_data_cdf, [1, 1, 1])
params_cdf_1
# Out:
# array([ 2.09130714e-04,  5.51079620e-07, -4.08223761e+00])

# %%
plt.scatter(x_data_cdf, y_data_cdf, label='data', marker='x', c='r')
x = np.linspace(1, 210, 210)
plt.plot(x, growth_curve_1(x, *params_cdf_1), 'b-', label='growth curve')

plt.title('COASTAL DOUGLAS-FIR GROWTH CURVE')
plt.xlabel('Age (years)')
plt.ylabel('AGB (Mg ha-1)')
plt.legend()
plt.show()

# %% [markdown]
# #### Amabilis Fir

# %%
# age
x_data_af = np.array([10,30,50,70,90,110,130,150,170,190,210])
# AGB
y_data_af = np.array([17.03, 66.89, 198.79, 137.92, 84.68, 155.24, 191.38, 195.36, 193.48, 174.57, 274.21])

# %%
params_af_1, _ = curve_fit(growth_curve_1, x_data_af, y_data_af, [1, 1, 1])
params_af_1
# Out:
# array([ 1.21894173e+01,  8.85445672e-03, -5.80240690e-01])

# %%
plt.scatter(x_data_af, y_data_af, label='data', marker='x', c='r')
x = np.linspace(1, 210, 210)
plt.plot(x, growth_curve_1(x, *params_af_1), 'b-', label='growth curve')

plt.title('AMABILIS FIR GROWTH CURVE')
plt.xlabel('Age (years)')
plt.ylabel('AGB (Mg ha-1)')
plt.legend()
plt.show()

# %% [markdown]
# ### Washington Data

# %% [markdown]
# #### Hemlock / Sitka

# %%
# age
x_data_hs = np.array([10,30,50,70,90,110,130,150,170,190,210])
# AGB
y_data_hs = np.array([52.34, 179.87, 243.72, 240.58, 239.97, 268.77, 275.11, 346.75, 410.24, 365.98, 496.13])

# %%
params_hs_1, _ = curve_fit(growth_curve_1, x_data_hs, y_data_hs, [1, 1, 1])
params_hs_1
# Out:
# array([33.09307273, -0.41609168, -0.13394883])

# %%
plt.scatter(x_data_hs, y_data_hs, label='data', marker='x', c='r')
x = np.linspace(1, 210, 210)
plt.plot(x, growth_curve_1(x, *params_hs_1), 'b-', label='growth curve')

plt.title('HEMLOCK / SITKA GROWTH CURVE')
plt.xlabel('Age (years)')
plt.ylabel('AGB (Mg ha-1)')
plt.legend()
plt.show()

# %% [markdown]
# #### Fir / Spruce / Mountain Hemlock

# %%
# age
x_data_fsm = np.array([10,30,50,70,90,110,130,150,170,190,210])
# AGB
y_data_fsm = np.array([29.15, 91.46, 126.46, 149.94, 162.66, 183.78, 220.71, 273.65, 304.81, 318.41, 436.59])

# %%
params_fsm_1, _ = curve_fit(growth_curve_1, x_data_fsm, y_data_fsm, [1, 1, 1])
params_fsm_1
# Out:
# array([16.66736486, -0.3716858 , -0.16591513])

# %%
plt.scatter(x_data_fsm, y_data_fsm, label='data', marker='x', c='r')
x = np.linspace(1, 210, 210)
plt.plot(x, growth_curve_1(x, *params_fsm_1), 'b-', label='growth curve')

plt.title('FIR / SPRUCE / MOUNTAIN HEMLOCK GROWTH CURVE')
plt.xlabel('Age (years)')
plt.ylabel('AGB (Mg ha-1)')
plt.legend()
plt.show()

# %% [markdown]
# #### Coastal & Interior Douglas-Fir

# %%
# age
x_data_df = np.array([10,30,50,70,90,110,130,150,170,190,210])
# AGB
y_data_df = np.array([52.34, 179.87, 243.72, 240.58, 239.97, 268.77, 275.11, 346.75, 410.24, 365.98, 496.13])

# %%
params_df_1, _ = curve_fit(growth_curve_1, x_data_df, y_data_df, [1, 1, 1])
params_df_1
# Out:
# array([33.09307273, -0.41609168, -0.13394883])

# %%
plt.scatter(x_data_df, y_data_df, label='data', marker='x', c='r')
x = np.linspace(1, 210, 210)
plt.plot(x, growth_curve_1(x, *params_df_1), 'b-', label='growth curve')

plt.title('COASTAL & INTERIOR DOUGLAS-FIR GROWTH CURVE')
plt.xlabel('Age (years)')
plt.ylabel('AGB (Mg ha-1)')
plt.legend()
plt.show()
